# %% [markdown]
# # Samip Sharma
# Course: Bsc Computing
# Student ID / Email: ssamip23@tbc.edu.np
#
# I am submitting Exam Paper 1.

# %% [markdown]
# ## My Ideal Programming Environment
#
# I believe I work **best** in a *quiet and organized* setting, free from distractions. My preferred tools include **Python** and **Jupyter Notebooks**, which allow for quick experimentation and visualization.
#
# In terms of physical environment, I like a **comfortable desk**, a **good keyboard**, and **dual monitors** to multitask efficiently. To stay organized, I often use a **to-do list**:
#
# - Code editor (VS Code)
# - Terminal for command-line tasks
# - Browser for research
#
# This setup helps me stay focused and productive during programming sessions.
